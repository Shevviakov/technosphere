# %% [markdown]
# ## Non-Graphical EDA

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
from __future__ import division
# %matplotlib inline

# %%
vg = pd.read_csv("vgsales.csv")

# %% [markdown]
# ### Data types

# %% [markdown]
# Просмотрим набор типов в данных:

# %%
vg.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# Взглянем на данные:

# %%
vg.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# На что стоит обратить внимание:

# %% [markdown]
# 1. Missing variables
# 2. Наличие временных или координатных переменных
# 3. Float vs. int переменные
# 4. Выявление категориальных переменных среди текстовых и числовых
# 5. Разделение ординальных переменных среди категориальных

# %% [markdown]
# Самая простая диагностика распределения - частоты:

# %%
vg.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
pub_counts = vg.Publisher.value_counts()
pub_counts
# Out:
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Eidos Interactive                          198
# Midway Games                               198
# 505 Games                                  192
# Microsoft Game Studios                     189
# Acclaim Entertainment                      184
# D3Publisher                                184
# Vivendi Games                              164
# Codemasters                                152
# Idea Factory                               129
# Deep Silver                                122
# Nippon Ichi Software                       105
# Zoo Digital Publishing                     104
# Majesco Entertainment                       92
#                                           ...
# Magical Company                              1
# 2D Boy                                       1
# Panther Software                             1
# Evolution Games                              1
# CBS Electronics                              1
# Mystique                                     1
# SCS Software                                 1
# Kool Kizz                                    1
# Riverhillsoft                                1
# Giga                                         1
# Game Arts                                    1
# Elite                                        1
# RED Entertainment                            1
# Her Interactive                              1
# American Softworks                           1
# Axela                                        1
# Wargaming.net                                1
# Quest                                        1
# Mitsui                                       1
# NDA Productions                              1
# TYO                                          1
# Interplay Productions                        1
# Interchannel-Holon                           1
# Simon & Schuster Interactive                 1
# Phantom EFX                                  1
# Sunflowers                                   1
# Nichibutsu                                   1
# MediaQuest                                   1
# UEP Systems                                  1
# CCP                                          1
# Name: Publisher, dtype: int64

# %% [markdown]
# Зачастую бывает полезно запихнуть все категории с низкими частотами в одну для последующего анализа

# %%
vg["New_Publisher"] = vg["Publisher"]
vg.loc[vg["Publisher"].isin(pub_counts[pub_counts<100].index), "New_Publisher"] = "Other"

# %%
vg.New_Publisher.value_counts()
# Out:
# Other                                     4487
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Eidos Interactive                          198
# Midway Games                               198
# 505 Games                                  192
# Microsoft Game Studios                     189
# Acclaim Entertainment                      184
# D3Publisher                                184
# Vivendi Games                              164
# Codemasters                                152
# Idea Factory                               129
# Deep Silver                                122
# Nippon Ichi Software                       105
# Zoo Digital Publishing                     104
# Name: New_Publisher, dtype: int64

# %% [markdown]
# Бывает полезно создать бинарные переменные для отсутсвующих значений в числовых переменных. Это поможет понять природу возникновения отсутствующих значений

# %%
vg["No_year"] = 0
vg.loc[pd.isnull(vg['Year']), "No_year"] = 1
vg["No_year"].sum()
# Out:
# 271

# %% [markdown]
# Еще одна важная переменная, которую стоит создать, если её еще нет - индекс порядка записей. Её анализ поможет получить дополнительную информацию о том, как данные собирались и позволит избежать некоторых ошибок в анализе

# %%
vg["New_index"] = vg.index
vg["New_index"].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: New_index, dtype: int64

# %% [markdown]
# Рекомендуется также проверять числовые переменные при помощи таблиц частот - это поможет нам обнаружить смешанные распределения

# %%
vg["Global_Sales"].value_counts().head()
# Out:
# 0.02    1071
# 0.03     811
# 0.04     645
# 0.05     632
# 0.01     618
# Name: Global_Sales, dtype: int64

# %% [markdown]
# Для определения взаимосвязей между категориальными переменными можно строить таблицы сопряженности:

# %%
ctab1 = pd.crosstab(vg["New_Publisher"], vg["Genre"])
ctab1
# Out:
# Genre                                   Action  Adventure  Fighting  Misc  \
# New_Publisher
# 505 Games                                   21          7        11    31
# Acclaim Entertainment                       14          4        31     5
# Activision                                 310         25         7   103
# Atari                                       54         17        37    26
# Capcom                                     154         22        58    11
# Codemasters                                  9          6         0     7
# D3Publisher                                 53         31         3    32
# Deep Silver                                 27         10         2     7
# Disney Interactive Studios                  96         29         0    44
# Eidos Interactive                           84          5         7     5
# Electronic Arts                            183         13        39    46
# Idea Factory                                28         81         0     5
# Konami Digital Entertainment               148         53        20    77
# Microsoft Game Studios                      21          3         5    34
# Midway Games                                27          4        25    20
# Namco Bandai Games                         248         58       134    97
# Nintendo                                    79         35        18   100
# Nippon Ichi Software                        13         12         2     3
# Other                                      633        616       250   526
# Sega                                       101         31        37    62
# Sony Computer Entertainment                 90         41        30   128
# Square Enix                                 52         10         3     6
# THQ                                        194         47        71    66
# Take-Two Interactive                        93         12         1    27
# Tecmo Koei                                 137         17        12    14
# Ubisoft                                    193         59        19   151
# Unknown                                     28         17         6    31
# Vivendi Games                               46          7         4     8
# Warner Bros. Interactive Entertainment     165          3        11    22
# Zoo Digital Publishing                       8          7         3    18
#
# Genre                                   Platform  Puzzle  Racing  \
# New_Publisher
# 505 Games                                      6      15       2
# Acclaim Entertainment                          5       9      44
# Activision                                    60       7      74
# Atari                                         21      22      36
# Capcom                                        46       6      13
# Codemasters                                    0       1      89
# D3Publisher                                   12      11       6
# Deep Silver                                    3       7       7
# Disney Interactive Studios                    20       3      14
# Eidos Interactive                              4       8      14
# Electronic Arts                               16       7     159
# Idea Factory                                   0       0       0
# Konami Digital Entertainment                  40      10      13
# Microsoft Game Studios                         6       1      22
# Midway Games                                  14       4      25
# Namco Bandai Games                            19      20      27
# Nintendo                                     112      74      37
# Nippon Ichi Software                           3       0       0
# Other                                        155     255     319
# Sega                                          52      22      48
# Sony Computer Entertainment                   66      12      65
# Square Enix                                    0       4       0
# THQ                                           85      17     101
# Take-Two Interactive                          11       1      20
# Tecmo Koei                                     1       0       5
# Ubisoft                                       70      24      52
# Unknown                                       10      17      13
# Vivendi Games                                 37       2      14
# Warner Bros. Interactive Entertainment         8       8       3
# Zoo Digital Publishing                         2      14      26
#
# Genre                                   Role-Playing  Shooter  Simulation  \
# New_Publisher
# 505 Games                                         10       18          41
# Acclaim Entertainment                              1       17           0
# Activision                                        41      159          23
# Atari                                             28       40           9
# Capcom                                            38       25           2
# Codemasters                                        3       20           3
# D3Publisher                                        4       12           6
# Deep Silver                                       17        5          17
# Disney Interactive Studios                         3        3           5
# Eidos Interactive                                  9       35           8
# Electronic Arts                                   35      139         116
# Idea Factory                                      13        0           0
# Konami Digital Entertainment                      37       40          86
# Microsoft Game Studios                            16       28          18
# Midway Games                                       4       17           0
# Namco Bandai Games                               151       37          29
# Nintendo                                         106       26          29
# Nippon Ichi Software                              69        1           0
# Other                                            534      322         262
# Sega                                              64       40          12
# Sony Computer Entertainment                       49       51          15
# Square Enix                                      129       16           4
# THQ                                                8       36          27
# Take-Two Interactive                               6       65           4
# Tecmo Koei                                        47        3          13
# Ubisoft                                           41       92         119
# Unknown                                           22       13          13
# Vivendi Games                                      1       30           1
# Warner Bros. Interactive Entertainment             0       10           0
# Zoo Digital Publishing                             0        8           1
#
# Genre                                   Sports  Strategy
# New_Publisher
# 505 Games                                   27         3
# Acclaim Entertainment                       52         2
# Activision                                 144        22
# Atari                                       56        17
# Capcom                                       3         3
# Codemasters                                 10         4
# D3Publisher                                 11         3
# Deep Silver                                 10        10
# Disney Interactive Studios                   1         0
# Eidos Interactive                            8        11
# Electronic Arts                            561        37
# Idea Factory                                 0         2
# Konami Digital Entertainment               280        28
# Microsoft Game Studios                      17        18
# Midway Games                                58         0
# Namco Bandai Games                          51        61
# Nintendo                                    55        32
# Nippon Ichi Software                         0         2
# Other                                      403       212
# Sega                                       135        35
# Sony Computer Entertainment                124        12
# Square Enix                                  0         9
# THQ                                         31        32
# Take-Two Interactive                       151        22
# Tecmo Koei                                  39        50
# Ubisoft                                     72        29
# Unknown                                     26         7
# Vivendi Games                                2        12
# Warner Bros. Interactive Entertainment       0         2
# Zoo Digital Publishing                      16         1

# %% [markdown]
# Для лучшего визуального определения взаимосвязей можно использовать цветовую схему:

# %%
from itable import *

# %%
resid = (ctab1 - stats.chi2_contingency(ctab1)[3])/np.sqrt(stats.chi2_contingency(ctab1)[3])

pt = PrettyTable(resid.reset_index(), tstyle=TableStyle(theme="theme1"))

cs1 = CellStyle()
cs1.set("background-color", "firebrick")
cs1.set("color", "white")

cs2 = CellStyle()
cs2.set("background-color", "royalblue")
cs2.set("color", "white")

for i in range(resid.shape[0]):
  for j in range(resid.shape[1]):
    if resid.iloc[i,j]>=2:
        pt.set_cell_style(style=cs1, rows=[i], cols=[j+1])
    elif resid.iloc[i,j]<=-2:
        pt.set_cell_style(style=cs2, rows=[i], cols=[j+1])

pt
# Out:
# <table style="color: black;border: 1px solid black;"><tr style="color: black;border: 1px solid black;"><td style="color: black;font-weight: bold;background-color: lightgray;">New_Publisher</td><td style="color: black;font-weight: bold;background-color: lightgray;">Action</td><td style="color: black;font-weight: bold;background-color: lightgray;">Adventure</td><td style="color: black;font-weight: bold;background-color: lightgray;">Fighting</td><td style="color: black;font-weight: bold;background-color: lightgray;">Misc</td><td style="color: black;font-weight: bold;background-color: lightgray;">Platform</td><td style="color: black;font-weight: bold;background-color: lightgray;">Puzzle</td><td style="color: black;font-weight: bold;background-color: lightgray;">Racing</td><td style="color: black;font-weight: bold;background-color: lightgray;">Role-Playing</td><td style="color: black;font-weight: bold;background-color: lightgray;">Shooter</td><td style="color: black;font-weight: bold;background-color: lightgray;">Simulation</td><td style="color: black;font-weight: bold;background-color: lightgray;">Sports</td><td style="color: black;font-weight: bold;background-color: lightgray;">Strategy</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">505 Games</td><td style="color: white;background-color: royalblue;">-2.8093615955</td><td style="color: white;background-color: royalblue;">-2.04312669416</td><td style="color: black;border: 1px solid black;">0.376364973091</td><td style="color: white;background-color: firebrick;">2.49593078804</td><td style="color: black;border: 1px solid black;">-1.3303646265</td><td style="color: white;background-color: firebrick;">3.17891496126</td><td style="color: white;background-color: royalblue;">-3.28072707016</td><td style="color: black;border: 1px solid black;">-1.74556037598</td><td style="color: black;border: 1px solid black;">0.722793998956</td><td style="color: white;background-color: firebrick;">9.78864656091</td><td style="color: black;border: 1px solid black;">-0.0379786376444</td><td style="color: black;border: 1px solid black;">-1.73605979445</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">Acclaim Entertainment</td><td style="color: white;background-color: royalblue;">-3.75973428943</td><td style="color: white;background-color: royalblue;">-2.71727014406</td><td style="color: white;background-color: firebrick;">7.0371825237</td><td style="color: white;background-color: royalblue;">-3.21836740838</td><td style="color: black;border: 1px solid black;">-1.54151680182</td><td style="color: black;border: 1px solid black;">0.997767483343</td><td style="color: white;background-color: firebrick;">8.08271000966</td><td style="color: white;background-color: royalblue;">-3.81989113829</td><td style="color: black;border: 1px solid black;">0.642037308116</td><td style="color: white;background-color: royalblue;">-3.09846472885</td><td style="color: white;background-color: firebrick;">5.07998099634</td><td style="color: white;background-color: royalblue;">-2.01811167742</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">Activision</td><td style="color: white;background-color: firebrick;">8.22985585888</td><td style="color: white;background-color: royalblue;">-5.81735962563</td><td style="color: white;background-color: royalblue;">-6.07063147421</td><td style="color: black;border: 1px solid black;">0.207151902078</td><td style="color: black;border: 1px solid black;">1.09298529427</td><td style="color: white;background-color: royalblue;">-4.65612481097</td><td style="color: black;border: 1px solid black;">0.0504702747762</td><td style="color: white;background-color: royalblue;">-4.97864922594</td><td style="color: white;background-color: firebrick;">9.32662068584</td><td style="color: white;background-color: royalblue;">-3.90778064385</t ...

# %% [markdown]
# Иногда бывает удобно разбить числовые переменные на группы и использовать их в таблицах сопряженности

# %%
bins_cut = vg.Global_Sales.quantile(q = np.arange(0,1.1,0.1))
vg["Global_Sales_Cut"] = pd.cut(vg["Global_Sales"], bins = bins_cut)

# %%
ctab2 = pd.crosstab(vg["Global_Sales_Cut"], vg["Genre"])
ctab2
# Out:
# Genre             Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Global_Sales_Cut
# (0.01, 0.02]         187        211        26    99        30      52      71
# (0.02, 0.05]         370        280        87   229        89     101     140
# (0.05, 0.08]         294        146        89   174        70      74     108
# (0.08, 0.12]         303        118        89   190        85      61     128
# (0.12, 0.17]         305         90        76   160        75      53     110
# (0.17, 0.25]         335         92        74   201        67      39     122
# (0.25, 0.38]         352         67       101   165        90      44     123
# (0.38, 0.61]         386         58        86   180        95      42     127
# (0.61, 1.21]         341         43        96   142       115      37     142
# (1.21, 82.74]        336         33        99   138       155      44     136
#
# Genre             Role-Playing  Shooter  Simulation  Sports  Strategy
# Global_Sales_Cut
# (0.01, 0.02]                83       83          70      86        73
# (0.02, 0.05]               189      133         123     218       129
# (0.05, 0.08]               144      112          98     188        73
# (0.08, 0.12]               141      111          75     212        80
# (0.12, 0.17]               131      102          59     240        51
# (0.17, 0.25]               161      111          74     267        56
# (0.25, 0.38]               142      105         104     269        71
# (0.38, 0.61]               134      147          92     300        45
# (0.61, 1.21]               148      170          77     279        41
# (1.21, 82.74]              174      205          70     237        24

# %% [markdown]
# Временные переменные бывает удобно переводить в числовые (UNIXTIME) и обрезать до года/месяца/дня

# %% [markdown]
# Для оценки взаимосвязи числовых переменных мы можем построить таблицы корреляции:

# %%
corr_table = vg.corr()
corr_table
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.178814 -0.401362 -0.379123 -0.267785    -0.332986
# Year          0.178814  1.000000 -0.091402  0.006014 -0.169316     0.041058
# NA_Sales     -0.401362 -0.091402  1.000000  0.767727  0.449787     0.634737
# EU_Sales     -0.379123  0.006014  0.767727  1.000000  0.435584     0.726385
# JP_Sales     -0.267785 -0.169316  0.449787  0.435584  1.000000     0.290186
# Other_Sales  -0.332986  0.041058  0.634737  0.726385  0.290186     1.000000
# Global_Sales -0.427407 -0.074735  0.941047  0.902836  0.611816     0.748331
# No_year       0.012533       NaN -0.007105 -0.013860 -0.022071    -0.010802
# New_index     1.000000  0.178811 -0.401352 -0.379113 -0.267777    -0.332978
#
#               Global_Sales   No_year  New_index
# Rank             -0.427407  0.012533   1.000000
# Year             -0.074735       NaN   0.178811
# NA_Sales          0.941047 -0.007105  -0.401352
# EU_Sales          0.902836 -0.013860  -0.379113
# JP_Sales          0.611816 -0.022071  -0.267777
# Other_Sales       0.748331 -0.010802  -0.332978
# Global_Sales      1.000000 -0.013931  -0.427395
# No_year          -0.013931  1.000000   0.012533
# New_index        -0.427395  0.012533   1.000000

# %% [markdown]
# Их также можно раскрасить для более простого восприятия:

# %%
corr_table2 = PrettyTable(corr_table.reset_index(), tstyle=TableStyle(theme="theme1"))

cs3 = CellStyle()
cs3.set("background-color", "gray")
#cs3.set("color", "gray")


for i in range(corr_table.shape[0]):
  for j in range(corr_table.shape[1]):
    if i == j:
        corr_table2.set_cell_style(style=cs3, rows=[i], cols=[j+1])
    elif corr_table.iloc[i,j]>=0.5:
        corr_table2.set_cell_style(style=cs1, rows=[i], cols=[j+1])
    elif corr_table.iloc[i,j]<=-0.5:
        corr_table2.set_cell_style(style=cs2, rows=[i], cols=[j+1])

corr_table2
# Out:
# <table style="color: black;border: 1px solid black;"><tr style="color: black;border: 1px solid black;"><td style="color: black;font-weight: bold;background-color: lightgray;">index</td><td style="color: black;font-weight: bold;background-color: lightgray;">Rank</td><td style="color: black;font-weight: bold;background-color: lightgray;">Year</td><td style="color: black;font-weight: bold;background-color: lightgray;">NA_Sales</td><td style="color: black;font-weight: bold;background-color: lightgray;">EU_Sales</td><td style="color: black;font-weight: bold;background-color: lightgray;">JP_Sales</td><td style="color: black;font-weight: bold;background-color: lightgray;">Other_Sales</td><td style="color: black;font-weight: bold;background-color: lightgray;">Global_Sales</td><td style="color: black;font-weight: bold;background-color: lightgray;">No_year</td><td style="color: black;font-weight: bold;background-color: lightgray;">New_index</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">Rank</td><td style="background-color: gray;">1.0</td><td style="color: black;border: 1px solid black;">0.178813639779</td><td style="color: black;border: 1px solid black;">-0.401362246889</td><td style="color: black;border: 1px solid black;">-0.379123469093</td><td style="color: black;border: 1px solid black;">-0.267784652351</td><td style="color: black;border: 1px solid black;">-0.332986424371</td><td style="color: black;border: 1px solid black;">-0.427406607989</td><td style="color: black;border: 1px solid black;">0.0125329705591</td><td style="color: white;background-color: firebrick;">0.999999997939</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">Year</td><td style="color: black;border: 1px solid black;">0.178813639779</td><td style="background-color: gray;">1.0</td><td style="color: black;border: 1px solid black;">-0.0914021622936</td><td style="color: black;border: 1px solid black;">0.00601388738378</td><td style="color: black;border: 1px solid black;">-0.169316218391</td><td style="color: black;border: 1px solid black;">0.0410576668702</td><td style="color: black;border: 1px solid black;">-0.0747347976157</td><td style="color: black;border: 1px solid black;">nan</td><td style="color: black;border: 1px solid black;">0.178811112247</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">NA_Sales</td><td style="color: black;border: 1px solid black;">-0.401362246889</td><td style="color: black;border: 1px solid black;">-0.0914021622936</td><td style="background-color: gray;">1.0</td><td style="color: white;background-color: firebrick;">0.76772674837</td><td style="color: black;border: 1px solid black;">0.44978740707</td><td style="color: white;background-color: firebrick;">0.634737271904</td><td style="color: white;background-color: firebrick;">0.941047357125</td><td style="color: black;border: 1px solid black;">-0.00710485128558</td><td style="color: black;border: 1px solid black;">-0.401352331164</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">EU_Sales</td><td style="color: black;border: 1px solid black;">-0.379123469093</td><td style="color: black;border: 1px solid black;">0.00601388738378</td><td style="color: white;background-color: firebrick;">0.76772674837</td><td style="background-color: gray;">1.0</td><td style="color: black;border: 1px solid black;">0.435584452809</td><td style="color: white;background-color: firebrick;">0.726384889374</td><td style="color: white;background-color: firebrick;">0.902835813482</td><td style="color: black;border: 1px solid black;">-0.0138600268886</td><td style="color: black;border: 1px solid black;">-0.379112926999</td></tr><tr style="color: black;border: 1px solid black;"><td style="color: black;border: 1px solid black;">JP_Sales</td><td style="color: black;border: 1px solid bl ...

# %% [markdown]
# Таблицы корреляции показывают нам только линейную зависимость, и только между числовыми переменными. Если нас интересует взаимосвясь в более широком смысле, мы можем использовать Mutual Information или другие похожие показатели:

# %%
from minepy import MINE
mine = MINE(alpha=0.5, c=15)

vg_for_mi = vg
for j in range(vg_for_mi.shape[1]):
    if vg_for_mi.dtypes[j] == "object":
        vg_for_mi.iloc[:,j] = pd.factorize(vg_for_mi.iloc[:,j])[0]

mi_frame = pd.DataFrame(np.nan, index = vg_for_mi.columns, columns = vg_for_mi.columns)
for j in range(vg_for_mi.shape[1]):
    for k in range(j+1, vg_for_mi.shape[1]):
        mine.compute_score(vg_for_mi.iloc[:,j], vg_for_mi.iloc[:,k])
        mic = np.around(mine.mic(), 3)
        mi_frame.iloc[j,k] = mic

# %%
mi_frame
# Out:
#                Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  \
# Rank            NaN  0.684     0.068  0.063  0.057      0.185     0.586
# Name            NaN    NaN     0.057  0.104  0.106      0.225     0.472
# Platform        NaN    NaN       NaN  0.628  0.063      0.120     0.156
# Year            NaN    NaN       NaN    NaN  0.040      0.221     0.070
# Genre           NaN    NaN       NaN    NaN    NaN      0.116     0.064
# Publisher       NaN    NaN       NaN    NaN    NaN        NaN     0.252
# NA_Sales        NaN    NaN       NaN    NaN    NaN        NaN       NaN
# EU_Sales        NaN    NaN       NaN    NaN    NaN        NaN       NaN
# JP_Sales        NaN    NaN       NaN    NaN    NaN        NaN       NaN
# Other_Sales     NaN    NaN       NaN    NaN    NaN        NaN       NaN
# Global_Sales    NaN    NaN       NaN    NaN    NaN        NaN       NaN
# New_Publisher   NaN    NaN       NaN    NaN    NaN        NaN       NaN
# No_year         NaN    NaN       NaN    NaN    NaN        NaN       NaN
# New_index       NaN    NaN       NaN    NaN    NaN        NaN       NaN
#
#                EU_Sales  JP_Sales  Other_Sales  Global_Sales  New_Publisher  \
# Rank              0.459     0.181        0.576         1.000          0.115
# Name              0.363     0.159        0.443         0.686          0.152
# Platform          0.185     0.196        0.112         0.067          0.093
# Year              0.077     0.092        0.033         0.044          0.091
# Genre             0.054     0.065        0.027         0.041          0.088
# Publisher         0.220     0.374        0.185         0.186          1.000
# NA_Sales          0.321     0.254        0.416         0.591          0.159
# EU_Sales            NaN     0.189        0.492         0.462          0.127
# JP_Sales            NaN       NaN        0.091         0.183          0.214
# Other_Sales         NaN       NaN          NaN         0.540          0.129
# Global_Sales        NaN       NaN          NaN           NaN          0.115
# New_Publisher       NaN       NaN          NaN           NaN            NaN
# No_year             NaN       NaN          NaN           NaN            NaN
# New_index           NaN       NaN          NaN           NaN            NaN
#
#                No_year  New_index
# Rank             0.047      1.000
# Name             0.056      0.684
# Platform         0.005      0.068
# Year             0.120      0.063
# Genre            0.001      0.057
# Publisher        0.044      0.185
# NA_Sales         0.007      0.586
# EU_Sales         0.004      0.459
# JP_Sales         0.004      0.181
# Other_Sales      0.002      0.576
# Global_Sales     0.010      1.000
# New_Publisher    0.037      0.115
# No_year            NaN      0.047
# New_index          NaN        NaN

# %% [markdown]
# Большинство статистических пакетов могут выводить набор основных статистик по каждой переменной:

# %%
vg.describe(include='all')
# Out:
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2006.406443
# std      4791.853933                          NaN      NaN      5.828981
# min         1.000000                          NaN      NaN   1980.000000
# 25%      4151.250000                          NaN      NaN   2003.000000
# 50%      8300.500000                          NaN      NaN   2007.000000
# 75%     12449.750000                          NaN      NaN   2010.000000
# max     16600.000000                          NaN      NaN   2020.000000
#
#          Genre        Publisher      NA_Sales      EU_Sales      JP_Sales  \
# count    16598            16540  16598.000000  16598.000000  16598.000000
# unique      12              578           NaN           NaN           NaN
# top     Action  Electronic Arts           NaN           NaN           NaN
# freq      3316             1351           NaN           NaN           NaN
# mean       NaN              NaN      0.264667      0.146652      0.077782
# std        NaN              NaN      0.816683      0.505351      0.309291
# min        NaN              NaN      0.000000      0.000000      0.000000
# 25%        NaN              NaN      0.000000      0.000000      0.000000
# 50%        NaN              NaN      0.080000      0.020000      0.000000
# 75%        NaN              NaN      0.240000      0.110000      0.040000
# max        NaN              NaN     41.490000     29.020000     10.220000
#
#          Other_Sales  Global_Sales New_Publisher       No_year     New_index
# count   16598.000000  16598.000000         16540  16598.000000  16598.000000
# unique           NaN           NaN            30           NaN           NaN
# top              NaN           NaN         Other           NaN           NaN
# freq             NaN           NaN          4487           NaN           NaN
# mean        0.048063      0.537441           NaN      0.016327   8298.500000
# std         0.188588      1.555028           NaN      0.126735   4791.574219
# min         0.000000      0.010000           NaN      0.000000      0.000000
# 25%         0.000000      0.060000           NaN      0.000000   4149.250000
# 50%         0.010000      0.170000           NaN      0.000000   8298.500000
# 75%         0.040000      0.470000           NaN      0.000000  12447.750000
# max        10.570000     82.740000           NaN      1.000000  16597.000000

# %% [markdown]
# Как мы видим, в выведенной таблице не указано количество уникальных значений для числовых переменных. На них стоит посмотреть, что получить представление о разнообразности распределения, и, возможно, найти категориальные переменные

# %%
for j in vg.columns:
    print j, vg[j].nunique()
# Out:
# Rank 16598
# Name 11493
# Platform 31
# Year 39
# Genre 12
# Publisher 578
# NA_Sales 409
# EU_Sales 305
# JP_Sales 244
# Other_Sales 157
# Global_Sales 623
# New_Publisher 30
# No_year 2
# New_index 16598

# %% [markdown]
# Можно выводить дополнительны показатели коэффициент ассиметрии, коэффициент эксцесса и среднее абсолютное отклонение

# %% [markdown]
# $$skew = \frac{\frac{1}{n}\sum(x_i-\bar{x})^3}{s^3} $$
#
# $$kurt = \frac{\frac{1}{n}\sum(x_i-\bar{x})^4}{s^4} $$

# %%
vg.Global_Sales.skew()
# Out:
# 17.400645097552452

# %% [markdown]
# Положительная величина говорит о том масса распределения смещена налево

# %%
vg.Global_Sales.kurtosis()
# Out:
# 603.93234615959341

# %%
vg.Global_Sales.mad()
# Out:
# 0.59071007325455005

# %% [markdown]
# ### Агрегирование

# %% [markdown]
# Агрегирование данных позволит нам получить доступ к еще большему объему информации. В случае, если речь идет об аддитивных показателях, например платежах, мы можем использовать меры концентрации, например коэффициент Джини.

# %%
def gini(list_of_values):
    sorted_list = sorted(list_of_values)
    height, area = 0, 0
    for value in sorted_list:
        height += value
        area += height - value / 2.
    fair_area = height * len(list_of_values) / 2.
    return (fair_area - area) / fair_area

# %%
Gini_coef = gini(vg.Global_Sales)
Gini_coef
# Out:
# 0.71394347734039754
