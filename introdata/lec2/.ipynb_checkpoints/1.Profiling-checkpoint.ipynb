# %% [markdown]
# # 1.1. Измерение времени выполнения.

# %% [markdown]
# Делать это из ipython мы уже умеем:

# %%
# %timeit [i**2 for i in xrange(1000)]
# Out:
# 10000 loops, best of 3: 72.6 µs per loop

# %%
# %%timeit def cube(x): return x**3
[cube(x) for x in xrange(1000)]
# Out:
# 10000 loops, best of 3: 170 µs per loop

# %% [markdown]
# Если мы хотим измерить время выполнения какого-либо скрипта, то можем пойти несколькими путями:

# %% [markdown]
# -- N: пример из книги Gorelick, High Perfomance Python.

# %%
# %%timeit
# %run gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.85650491714 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.88900995255 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.74493312836 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.79333400726 seconds
# 1 loops, best of 3: 7.41 s per loop

# %%
# %run -t gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.80224919319 seconds
#
# IPython CPU timings (estimated):
#   User   :       7.36 s.
#   System :       0.09 s.
# Wall time:       7.49 s.

# %% [markdown]
# --N: brew install gnu-time

# %%
# !gtime -p --verbose python gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 6.87575483322 seconds
# 	Command being timed: "python gorelick.py"
# 	User time (seconds): 7.41
# 	System time (seconds): 0.13
# 	Percent of CPU this job got: 99%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:07.61
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 520011776
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 35862
# 	Voluntary context switches: 0
# 	Involuntary context switches: 6087
# 	Swaps: 0
# 	File system inputs: 0
# 	File system outputs: 0
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %% [markdown]
# -- N: https://developer.apple.com/library/content/documentation/Performance/Conceptual/ManagingMemory/Articles/AboutMemory.html

# %% [markdown]
# Относительно дорогой (относительно прочих) является "Major (requiring I/O) page faults" - обмен данными между RAM и диском.

# %% [markdown]
# # 1.2. cProfile.

# %% [markdown]
# https://docs.python.org/2/library/profile.html#module-cProfile

# %% [markdown]
# cProfile может использоваться как внутри модуля для оценки времени выполнения отдельной функции, так же как и средство измерения всего скрипта в целом.

# %%
# !python -m cProfile -s cumulative gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 11.4670190811 seconds
#          36221992 function calls in 12.405 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.036    0.036   12.405   12.405 gorelick.py:1(<module>)
#         1    0.752    0.752   12.368   12.368 gorelick.py:7(calc_pure_python)
#         1    8.903    8.903   11.467   11.467 gorelick.py:40(calculate_z_serial_purepython)
#  34219980    2.537    0.000    2.537    0.000 {abs}
#   2002000    0.143    0.000    0.143    0.000 {method 'append' of 'list' objects}
#         1    0.027    0.027    0.027    0.027 {range}
#         1    0.006    0.006    0.006    0.006 {sum}
#         2    0.000    0.000    0.000    0.000 {time.time}
#         4    0.000    0.000    0.000    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# -- N:
# gorelick.py:1(<module>) - точка входа;
# calc_pure_python - основная функция модуля;
# calculate_z_serial_purepython - один вызов внутри calc_pure_python.

# %% [markdown]
# Можно увидеть, что cProfile позволет достаточно удобно разобрать время выполнения каждой функции в отдельности, но о происходящим внтури каждой функции догадаться тяжело.

# %% [markdown]
# # 1.3. line_profiler: использование CPU.

# %% [markdown]
# https://github.com/rkern/line_profiler

# %% [markdown]
# -- N: pip install line_profiler

# %%
# !kernprof -l -v gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 84.5487709045 seconds
# Wrote profile results to gorelick.py.lprof
# Timer unit: 1e-06 s
#
# Total time: 46.9797 s
# File: gorelick.py
# Function: calculate_z_serial_purepython at line 40
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     40                                           @profile
#     41                                           def calculate_z_serial_purepython(maxiter, zs, cs):
#     42                                               """Calculate output list using Julia update rule"""
#     43         1         5323   5323.0      0.0      output = [0] * len(zs)
#     44   1000001       399176      0.4      0.8      for i in range(len(zs)):
#     45   1000000       358128      0.4      0.8          n=0
#     46   1000000       407067      0.4      0.9          z = zs[i]
#     47   1000000       390832      0.4      0.8          c = cs[i]
#     48  34219980     17009800      0.5     36.2          while abs(z) < 2 and n < maxiter:
#     49  33219980     14961894      0.5     31.8              z=z*z+c
#     50  33219980     13036351      0.4     27.7              n+=1
#     51   1000000       411165      0.4      0.9          output[i] = n
#     52         1            3      3.0      0.0      return output

# %% [markdown]
# -- N: hits - количество вызовов данной строчки.

# %% [markdown]
# Можно заметить, что недостатки cProfile устранены. Можно увидеть подробный разбор времени выполнения каждой строчки в интересующей нас функции.

# %% [markdown]
# --N: для дальнейшего анализа цикл while следует переписать как while True: ... if (cond): break else: continue

# %% [markdown]
# # 1.4. memory_profiler: использование RAM.

# %% [markdown]
# https://pypi.python.org/pypi/memory_profiler

# %% [markdown]
# -- N: используйте аккуратно (на меньшей проблеме), так как время выполнения увеличивается минимум на порядок.

# %%
# !python -m memory_profiler gorelick.py
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 2354.08766103 seconds
# Filename: gorelick.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#      7   21.469 MiB    0.000 MiB   @profile
#      8                             def calc_pure_python(desired_width, max_iterations):
#      9   21.469 MiB    0.000 MiB       x_step = (float(x2 - x1) / float(desired_width))
#     10   21.469 MiB    0.000 MiB       y_step = (float(y1 - y2) / float(desired_width))
#     11   21.469 MiB    0.000 MiB       x=[]
#     12   21.469 MiB    0.000 MiB       y=[]
#     13   21.469 MiB    0.000 MiB       ycoord = y2
#     14   21.488 MiB    0.020 MiB       while ycoord > y1:
#     15   21.488 MiB    0.000 MiB           y.append(ycoord)
#     16   21.488 MiB    0.000 MiB           ycoord += y_step
#     17   21.488 MiB    0.000 MiB           xcoord = x1
#     18   21.520 MiB    0.031 MiB       while xcoord < x2:
#     19   21.520 MiB    0.000 MiB           x.append(xcoord)
#     20   21.520 MiB    0.000 MiB           xcoord += x_step
#     21                                 # Build a list of coordinates and the initial condition for each cell.
#     22                                 # Note that our initial condition is a constant and could easily be removed; # we use it to simulate a real-world scenario with several inputs to
#     23                                 # our function.
#     24   21.520 MiB    0.000 MiB       zs=[]
#     25   21.520 MiB    0.000 MiB       cs=[]
#     26   85.812 MiB   64.293 MiB       for ycoord in y:
#     27   85.812 MiB    0.000 MiB           for xcoord in x:
#     28   85.812 MiB    0.000 MiB               zs.append(complex(xcoord, ycoord))
#     29   85.812 MiB    0.000 MiB               cs.append(complex(c_real, c_imag))
#     30   85.812 MiB    0.000 MiB       print "Length of x:", len(x)
#     31   85.812 MiB    0.000 MiB       print "Total elements:", len(zs)
#     32   85.812 MiB    0.000 MiB       start_time = time.time()
#     33  140.168 MiB   54.355 MiB       output = calculate_z_serial_purepython(max_iterations, zs, cs)
#     34  140.168 MiB    0.000 MiB       end_time = time.time()
#     35  140.168 MiB    0.000 MiB       secs = end_time - start_time
#     36  140.172 MiB    0.004 MiB       print calculate_z_serial_purepython.func_name + " took", secs, "seconds"
#     37                                 # This sum is expected for a 1000^2 grid with 300 iterations. # It catches minor errors we might introduce when we're
#     38                                 # working on a fixed set of inputs.
#     39  140.738 MiB    0.566 MiB       assert sum(output) == 33219980
#
#
# Filename: gorelick.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#     41   85.816 MiB    0.000 MiB   @profile
#     42                             def calculate_z_serial_purepython(maxiter, zs, cs):
#     43                                 """Calculate output list using Julia update rule"""
#     44   93.449 MiB    7.633 MiB       output = [0] * len(zs)
#     45  140.168 MiB   46.719 MiB       for i in range(len(zs)):
#     46  140.168 MiB    0.000 MiB           n=0
#     47  140.168 MiB    0.000 MiB           z = zs[i]
#     48  140.168 MiB    0.000 MiB           c = cs[i]
#     49  140.168 MiB    0.000 MiB           while abs(z) < 2 and n < maxiter:
#     50  140.168 MiB    0.000 MiB               z=z*z+c
#     51  140.168 MiB    0.000 MiB               n+=1
#     52  140.168 MiB    0.000 MiB           output[i] = n
#     53  140.168 MiB    0.000 MiB       return output

# %% [markdown]
# # 1.5. dis: для самых крутых.

# %% [markdown]
# Позволяет изучить байткод для Python Virtual Machine.

# %%
def fn_expressive(upper = 1000000):
    total = 0
    for n in xrange(upper):
        total += n
    return total

def fn_terse(upper = 1000000):
    return sum(xrange(upper))

# %%
import dis
dis.dis(fn_expressive)
# Out:
#   2           0 LOAD_CONST               1 (0)
#               3 STORE_FAST               1 (total)
#
#   3           6 SETUP_LOOP              30 (to 39)
#               9 LOAD_GLOBAL              0 (xrange)
#              12 LOAD_FAST                0 (upper)
#              15 CALL_FUNCTION            1
#              18 GET_ITER
#         >>   19 FOR_ITER                16 (to 38)
#              22 STORE_FAST               2 (n)
#
#   4          25 LOAD_FAST                1 (total)
#              28 LOAD_FAST                2 (n)
#              31 INPLACE_ADD
#              32 STORE_FAST               1 (total)
#              35 JUMP_ABSOLUTE           19
#         >>   38 POP_BLOCK
#
#   5     >>   39 LOAD_FAST                1 (total)
#              42 RETURN_VALUE

# %%
dis.dis(fn_terse)
# Out:
#   8           0 LOAD_GLOBAL              0 (sum)
#               3 LOAD_GLOBAL              1 (xrange)
#               6 LOAD_FAST                0 (upper)
#               9 CALL_FUNCTION            1
#              12 CALL_FUNCTION            1
#              15 RETURN_VALUE

# %% [markdown]
# # Дополнительный материал 1: Декораторы

# %% [markdown]
# Как вы заметили, во многих местах для профилирования мы использовали т.н. декоратор вида "@decorator_name". Декоратор, по сути, это т.н. "синтаксический сахар" (syntactic sugar), введенный в PEP 318 (https://www.python.org/dev/peps/pep-0318/).

# %% [markdown]
# Для понимания декораторов у нас уже все есть:
# * правило LEGB для разрешения имен;
# * понимание функций как "объектов первого класса".

# %% [markdown]
# Хороший пример композиции функций (http://thecodeship.com/patterns/guide-to-python-function-decorators/):

# %%
def get_text(name):
   return "lorem ipsum, {0} dolor sit amet".format(name)

def p_decorate(func):
   def func_wrapper(name):
       return "<p>{0}</p>".format(func(name))
   return func_wrapper

my_get_text = p_decorate(get_text)

print my_get_text("John")

# <p>Outputs lorem ipsum, John dolor sit amet</p>
# Out:
# <p>lorem ipsum, John dolor sit amet</p>

# %% [markdown]
# Для удобства можно переписать так:

# %%
def p_decorate(func):
   def func_wrapper(name):
       return "<p>{0}</p>".format(func(name))
   return func_wrapper

@p_decorate
def get_text(name):
   return "lorem ipsum, {0} dolor sit amet".format(name)

print get_text("John")

# Outputs <p>lorem ipsum, John dolor sit amet</p>
# Out:
# <p>lorem ipsum, John dolor sit amet</p>

# %% [markdown]
# -- В: может ли p_decorate изменить параметр name?

# %% [markdown]
# Никто не запрещает использовать композицию декораторов:

# %%
def p_decorate(func):
   def func_wrapper(name):
       return "<p>{0}</p>".format(func(name))
   return func_wrapper

def strong_decorate(func):
    def func_wrapper(name):
        return "<strong>{0}</strong>".format(func(name))
    return func_wrapper

def div_decorate(func):
    def func_wrapper(name):
        return "<div>{0}</div>".format(func(name))
    return func_wrapper

# %% [markdown]
# Еще раз о том, что здесь происходит:
# - p_decorate принимает в качестве параметра функцию и возвращаемый ей результат оборачивает ("декорирует") в функцию func_wrapper (которая, в свою очередь, просто вставляет результат исполнения в строку с тегами).

# %%
@div_decorate
@p_decorate
@strong_decorate
def get_text(name):
   return "lorem ipsum, {0} dolor sit amet".format(name)

print get_text("John")

# аналог get_text = div_decorate(p_decorate(strong_decorate(get_text)))
# Out:
# <div><p><strong>lorem ipsum, John dolor sit amet</strong></p></div>

# %% [markdown]
# Декораторы могут также принимать параметры:

# %%
def tags(tag_name):
    def tags_decorator(func):
        def func_wrapper(name):
            return "<{0}>{1}</{0}>".format(tag_name, func(name))
        return func_wrapper
    return tags_decorator

@tags("p")
def get_text(name):
    return "Hello "+name

print get_text("John")

# Outputs <p>Hello John</p>
# Out:
# <p>Hello John</p>

# %%
print get_text.__name__ # get_text
print get_text.__doc__ # returns some text
print get_text.__module__ # __main__
# Out:
# func_wrapper
# None
# __main__

# %% [markdown]
# Для того, чтобы не иметь проблем с разбором кода при использовании декораторов рекомендуется использовать декоратор wraps из модуля functools.

# %%
from functools import wraps

def tags(tag_name):
    def tags_decorator(func):
        @wraps(func)
        def func_wrapper(name):
            return "<{0}>{1}</{0}>".format(tag_name, func(name))
        return func_wrapper
    return tags_decorator

@tags("p")
def get_text(name):
    """returns some text"""
    return "Hello "+name

print get_text.__name__ # get_text
print get_text.__doc__ # returns some text
print get_text.__module__ # __main__
# Out:
# get_text
# returns some text
# __main__

# %% [markdown]
# Достаточно удобно использовать декораторы в рамках парадигмы ООП. Как мы помним, методы - это те же функции, у которых первый параметр -  ссылка на исполняющий объект.

# %%
def p_decorate(func):
   def func_wrapper(self):
       return "<p>{0}</p>".format(func(self))
   return func_wrapper

class Person(object):
    def __init__(self):
        self.name = "John"
        self.family = "Doe"

    @p_decorate
    def get_fullname(self):
        return self.name+" "+self.family

my_person = Person()
print my_person.get_fullname()
# Out:
# <p>John Doe</p>

# %% [markdown]
# Очень удобны в таком случае декораторы @getter и @setter:

# %%
class Person(object):
    def __init__(self):
        self._name = "John"
        self._family = "Doe"

    @property
    def name(self):
        print "getter of name called"
        return self._name

    @name.setter
    def name(self, value):
        print "setter of name called"
        self._name = value

    @name.deleter
    def name(self):
        print "deleter of name called"
        del self._name

# %%
p = Person()
p.name
# Out:
# getter of name called
# 'John'

# %%
p.name = 'Sam'
# Out:
# setter of name called

# %%
p.name
# Out:
# getter of name called
# 'Sam'

# %%
del p.name
# Out:
# deleter of name called

# %% [markdown]
# Подробнее об этом декораторе можно прочитать тут - https://docs.python.org/3/library/functions.html#property .

# %% [markdown]
# # Дополнительный материал 2: Дебаггеры

# %% [markdown]
# https://pymotw.com/2/pdb/

# %% [markdown]
# Для использования в IPython рекомендуется ipdb.

# %% [markdown]
# --N : ipdb

# %% [markdown]
# Список комманд находится тут: http://frid.github.io/blog/2014/06/05/python-ipdb-cheatsheet/ .
#
# Описание того, как использовать ipdb в ячейках IPython - тут: http://devmartin.com/blog/2014/10/trigger-ipdb-within-ipython-notebook/

# %%
from IPython.core.debugger import Tracer
def fobar(n):
    x = 1337
    y = x + n
    Tracer()() #this one triggers the debugger
    return y

fobar(3)
# Out:
# > <ipython-input-43-19f589c6ab38>(6)fobar()
#       5     Tracer()() #this one triggers the debugger
# ----> 6     return y
#       7
#
# ipdb> н
# *** SyntaxError: invalid syntax (<stdin>, line 1)
# ipdb> y
# 1340
# ipdb> exit
# Exiting Debugger.

# %% [markdown]
# # Дополнительный материал 3: requests

# %% [markdown]
# requests - это т.н. "user-friendly" модуль для обмена запросами через интернет. Сетевое программирование мы в рамках данного курса не рассматриваем, однако часто может встретиться ситуация, когда вам нужно получить ответ от API стороннего сервиса или скачать файл, который расположен на удаленном сервере.

# %%
import requests

# %% [markdown]
# http://stackoverflow.com/questions/16694907/how-to-download-large-file-in-python-with-requests-py

# %%
def download_file(url):
    local_filename = url.split('/')[-1]
    # NOTE the stream=True parameter
    r = requests.get(url, stream=True)
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                #f.flush() commented by recommendation from J.F.Sebastian
    return local_filename

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8655789?',
#    u'display_login': u'codecov-io',
#    u'gravatar_id': u'',
#    u'id': 8655789,
#    u'login': u'codecov-io',
#    u'url': u'https://api.github.com/users/codecov-io'},
#   u'created_at': u'2016-09-26T11:20:46Z',
#   u'id': u'4617188995',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7815877?',
#    u'gravatar_id': u'',
#    u'id': 7815877,
#    u'login': u'spring-cloud',
#    u'url': u'https://api.github.com/orgs/spring-cloud'},
#   u'payload': {u'action': u'created',
#    u'comment': {u'body': u'## [Current coverage](https://codecov.io/gh/spring-cloud/spring-cloud-config/pull/513?src=pr) is 68.81% (diff: 100%)\n> Merging [#513](https://codecov.io/gh/spring-cloud/spring-cloud-config/pull/513?src=pr) into [master](https://codecov.io/gh/spring-cloud/spring-cloud-config/branch/master?src=pr) will not change coverage\n\n```diff\n@@             master       #513   diff @@\n==========================================\n  Files            60         60          \n  Lines          2046       2046          \n  Methods           0          0          \n  Messages          0          0          \n  Branches        341        341          \n==========================================\n  Hits           1408       1408          \n  Misses          499        499          \n  Partials        139        139          \n```\n\n> Powered by [Codecov](https://codecov.io?src=pr). Last update [c363810...8b31d43](https://codecov.io/gh/spring-cloud/spring-cloud-config/compare/c3638109be8d44c5198f0536af882fcbeb5e4c37...8b31d4349dd6b00ec09b2c8d333967fdb6c501d1?src=pr)',
#     u'created_at': u'2016-09-26T11:20:46Z',
#     u'html_url': u'https://github.com/spring-cloud/spring-cloud-config/pull/513#issuecomment-249543803',
#     u'id': 249543803,
#     u'issue_url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/513',
#     u'updated_at': u'2016-09-26T11:20:46Z',
#     u'url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/comments/249543803',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8655789?v=3',
#      u'events_url': u'https://api.github.com/users/codecov-io/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/codecov-io/followers',
#      u'following_url': u'https://api.github.com/users/codecov-io/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/codecov-io/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/codecov-io',
#      u'id': 8655789,
#      u'login': u'codecov-io',
#      u'organizations_url': u'https://api.github.com/users/codecov-io/orgs',
#      u'received_events_url': u'https://api.github.com/users/codecov-io/received_events',
#      u'repos_url': u'https://api.github.com/users/codecov-io/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/codecov-io/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/codecov-io/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/codecov-io'}},
#    u'issue': {u'assignee': None,
#     u'assignees': [],
#     u'body': u'',
#     u'closed_at': None,
#     u'comments': 2,
#     u'comments_url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/513/comments',
#     u'created_at': u'2016-09-26T11:04:44Z',
#     u'events_url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/513/events',
#     u'html_url': u'https://github.com/spring-cloud/spring-cloud-config/pull/513',
#     u'id': 179199145,
#     u'labels': [],
#     u'labels_url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/513/labels{/name}',
#     u'locked': False,
#     u'milestone': None,
#     u'number': 513,
#     u'pull_request': {u'diff_url': u'https://github.com/spring-cloud/spring-cloud-config/pull/513.diff',
#      u'html_url': u'https://github.com/spring-cloud/spring-cloud-config/pull/513',
#      u'patch_url': u'https://github.com/spring-cloud/spring-cloud-config/pull/513.patch',
#      u'url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/pulls/513'},
#     u'repository_url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config',
#     u'state': u'open',
#     u'title': u'Java 8 JCE link fixed',
#     u'updated_at': u'2016-09-26T11:20:46Z',
#     u'url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config/issues/513',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1488134?v=3',
#      u'events_url': u'https://api.github.com/users/douglarek/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/douglarek/followers',
#      u'following_url': u'https://api.github.com/users/douglarek/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/douglarek/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/douglarek',
#      u'id': 1488134,
#      u'login': u'douglarek',
#      u'organizations_url': u'https://api.github.com/users/douglarek/orgs',
#      u'received_events_url': u'https://api.github.com/users/douglarek/received_events',
#      u'repos_url': u'https://api.github.com/users/douglarek/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/douglarek/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/douglarek/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/douglarek'}}},
#   u'public': True,
#   u'repo': {u'id': 20811348,
#    u'name': u'spring-cloud/spring-cloud-config',
#    u'url': u'https://api.github.com/repos/spring-cloud/spring-cloud-config'},
#   u'type': u'IssueCommentEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/11541477?',
#    u'display_login': u'michaelroland',
#    u'gravatar_id': u'',
#    u'id': 11541477,
#    u'login': u'michaelroland',
#    u'url': u'https://api.github.com/users/michaelroland'},
#   u'created_at': u'2016-09-26T11:20:46Z',
#   u'id': u'4617188989',
#   u'payload': {u'action': u'started'},
#   u'public': True,
#   u'repo': {u'id': 47636700,
#    u'name': u'johnzweng/nexus_bcm2079x_configurations',
#    u'url': u'https://api.github.com/repos/johnzweng/nexus_bcm2079x_configurations'},
#   u'type': u'WatchEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/17061547?',
#    u'display_login': u'Khmelov',
#    u'gravatar_id': u'',
#    u'id': 17061547,
#    u'login': u'Khmelov',
#    u'url': u'https://api.github.com/users/Khmelov'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188978',
#   u'payload': {u'before': u'e522b52cc8404677b5025c600dcb8edc02b4f143',
#    u'commits': [{u'author': {u'email': u'123', u'name': u'SpaiR'},
#      u'distinct': True,
#      u'message': u'jd01_15\nA,B \u0438 C',
#      u'sha': u'7b74d7fa3a4e8231327eaa6bfb6572e079ff9231',
#      u'url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/commits/7b74d7fa3a4e8231327eaa6bfb6572e079ff9231'},
#     {u'author': {u'email': u'Khmelov@users.noreply.github.com',
#       u'name': u'\u0410\u043b\u0435\u043a\u0441\u0430\u043d\u0434\u0440 \u0425\u043c\u0435\u043b\u0435\u0432'},
#      u'distinct': True,
#      u'message': u'Merge pull request #81 from SpaiR/jd01_15\n\n\u041f\u0440\u0438\u043c\u0448\u0438\u0446: JD01_15',
#      u'sha': u'9cfb3936ea64c64d9caec06c25e82db6b4418681',
#      u'url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/commits/9cfb3936ea64c64d9caec06c25e82db6b4418681'}],
#    u'distinct_size': 2,
#    u'head': u'9cfb3936ea64c64d9caec06c25e82db6b4418681',
#    u'push_id': 1316921996,
#    u'ref': u'refs/heads/master',
#    u'size': 2},
#   u'public': True,
#   u'repo': {u'id': 67041809,
#    u'name': u'Khmelov/JD2016-08-22',
#    u'url': u'https://api.github.com/repos/Khmelov/JD2016-08-22'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/11567?',
#    u'display_login': u'dpino',
#    u'gravatar_id': u'',
#    u'id': 11567,
#    u'login': u'dpino',
#    u'url': u'https://api.github.com/users/dpino'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188962',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1576566?',
#    u'gravatar_id': u'',
#    u'id': 1576566,
#    u'login': u'Igalia',
#    u'url': u'https://api.github.com/orgs/Igalia'},
#   u'payload': {u'action': u'created',
#    u'comment': {u'body': u'Besides nit, LGTM.',
#     u'created_at': u'2016-09-26T11:20:45Z',
#     u'html_url': u'https://github.com/Igalia/snabb/pull/455#issuecomment-249543802',
#     u'id': 249543802,
#     u'issue_url': u'https://api.github.com/repos/Igalia/snabb/issues/455',
#     u'updated_at': u'2016-09-26T11:20:45Z',
#     u'url': u'https://api.github.com/repos/Igalia/snabb/issues/comments/249543802',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/11567?v=3',
#      u'events_url': u'https://api.github.com/users/dpino/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/dpino/followers',
#      u'following_url': u'https://api.github.com/users/dpino/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/dpino/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/dpino',
#      u'id': 11567,
#      u'login': u'dpino',
#      u'organizations_url': u'https://api.github.com/users/dpino/orgs',
#      u'received_events_url': u'https://api.github.com/users/dpino/received_events',
#      u'repos_url': u'https://api.github.com/users/dpino/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/dpino/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/dpino/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/dpino'}},
#    u'issue': {u'assignee': {u'avatar_url': u'https://avatars.githubusercontent.com/u/11567?v=3',
#      u'events_url': u'https://api.github.com/users/dpino/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/dpino/followers',
#      u'following_url': u'https://api.github.com/users/dpino/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/dpino/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/dpino',
#      u'id': 11567,
#      u'login': u'dpino',
#      u'organizations_url': u'https://api.github.com/users/dpino/orgs',
#      u'received_events_url': u'https://api.github.com/users/dpino/received_events',
#      u'repos_url': u'https://api.github.com/users/dpino/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/dpino/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/dpino/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/dpino'},
#     u'assignees': [{u'avatar_url': u'https://avatars.githubusercontent.com/u/11567?v=3',
#       u'events_url': u'https://api.github.com/users/dpino/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/dpino/followers',
#       u'following_url': u'https://api.github.com/users/dpino/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/dpino/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/dpino',
#       u'id': 11567,
#       u'login': u'dpino',
#       u'organizations_url': u'https://api.github.com/users/dpino/orgs',
#       u'received_events_url': u'https://api.github.com/users/dpino/received_events',
#       u'repos_url': u'https://api.github.com/users/dpino/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/dpino/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/dpino/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/dpino'}],
#     u'body': u'The lwAFTR sends ICMPv6 unreachable (code 5) messages if it gets a message\r\nfrom a bad softwire (ie, from a B4 that is not in the binding table, or to\r\na br address that is not associated with that B4). If a br address can be\r\nassociated with the IPv6 address being replied to, use that as the source\r\naddress; otherwise, use the IPv6 address it was sent to.',
#     u'closed_at': None,
#     u'comments': 2,
#     u'comments_url': u'https://api.github.com/repos/Igalia/snabb/issues/455/comments',
#     u'created_at': u'2016-09-24T14:05:04Z',
#     u'events_url': u'https://api.github.com/repos/Igalia/snabb/issues/455/events',
#     u'html_url': u'https://github.com/Igalia/snabb/pull/455',
#     u'id': 179031806,
#     u'labels': [],
#     u'labels_url': u'https://api.github.com/repos/Igalia/snabb/issues/455/labels{/name}',
#     u'locked': False,
#     u'milestone': None,
#     u'number': 455,
#     u'pull_request': {u'diff_url': u'https://github.com/Igalia/snabb/pull/455.diff',
#      u'html_url': u'https://github.com/Igalia/snabb/pull/455',
#      u'patch_url': u'https://github.com/Igalia/snabb/pull/455.patch',
#      u'url': u'https://api.github.com/repos/Igalia/snabb/pulls/455'},
#     u'repository_url': u'https://api.github.com/repos/Igalia/snabb',
#     u'state': u'open',
#     u'title': u'If there is a br address for a bad softwire, use it',
#     u'updated_at': u'2016-09-26T11:20:45Z',
#     u'url': u'https://api.github.com/repos/Igalia/snabb/issues/455',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1588250?v=3',
#      u'events_url': u'https://api.github.com/users/kbara/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/kbara/followers',
#      u'following_url': u'https://api.github.com/users/kbara/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/kbara/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/kbara',
#      u'id': 1588250,
#      u'login': u'kbara',
#      u'organizations_url': u'https://api.github.com/users/kbara/orgs',
#      u'received_events_url': u'https://api.github.com/users/kbara/received_events',
#      u'repos_url': u'https://api.github.com/users/kbara/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/kbara/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/kbara/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/kbara'}}},
#   u'public': True,
#   u'repo': {u'id': 34452469,
#    u'name': u'Igalia/snabb',
#    u'url': u'https://api.github.com/repos/Igalia/snabb'},
#   u'type': u'IssueCommentEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7131721?',
#    u'display_login': u'andrevez',
#    u'gravatar_id': u'',
#    u'id': 7131721,
#    u'login': u'andrevez',
#    u'url': u'https://api.github.com/users/andrevez'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188960',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7923032?',
#    u'gravatar_id': u'',
#    u'id': 7923032,
#    u'login': u'ZeoAlliance',
#    u'url': u'https://api.github.com/orgs/ZeoAlliance'},
#   u'payload': {u'before': u'c15e5aa5f6c52a0f281561cf67f0dd596ff20efa',
#    u'commits': [{u'author': {u'email': u'vez@zeoalliance.com',
#       u'name': u'vez'},
#      u'distinct': True,
#      u'message': u'HF',
#      u'sha': u'77338f0a72ac287eccc5a375ddde0e1715f987e7',
#      u'url': u'https://api.github.com/repos/ZeoAlliance/capitoshka_aws_hackaton/commits/77338f0a72ac287eccc5a375ddde0e1715f987e7'}],
#    u'distinct_size': 1,
#    u'head': u'77338f0a72ac287eccc5a375ddde0e1715f987e7',
#    u'push_id': 1316921989,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 67721096,
#    u'name': u'ZeoAlliance/capitoshka_aws_hackaton',
#    u'url': u'https://api.github.com/repos/ZeoAlliance/capitoshka_aws_hackaton'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1634307?',
#    u'display_login': u'DryRun',
#    u'gravatar_id': u'',
#    u'id': 1634307,
#    u'login': u'DryRun',
#    u'url': u'https://api.github.com/users/DryRun'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188951',
#   u'payload': {u'action': u'closed',
#    u'number': 1,
#    u'pull_request': {u'_links': {u'comments': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/1/comments'},
#      u'commits': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1/commits'},
#      u'html': {u'href': u'https://github.com/DryRun/levelOneHCALFM/pull/1'},
#      u'issue': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/1'},
#      u'review_comment': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/comments{/number}'},
#      u'review_comments': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1/comments'},
#      u'self': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1'},
#      u'statuses': {u'href': u'https://api.github.com/repos/DryRun/levelOneHCALFM/statuses/a24d8ab9c04d216aba613b7ff82f1e93b7d8fa06'}},
#     u'additions': 110,
#     u'assignee': None,
#     u'assignees': [],
#     u'base': {u'label': u'DryRun:PartitionMaskingFromFEDList',
#      u'ref': u'PartitionMaskingFromFEDList',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/{archive_format}{/ref}',
#       u'assignees_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/branches{/branch}',
#       u'clone_url': u'https://github.com/DryRun/levelOneHCALFM.git',
#       u'collaborators_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/contributors',
#       u'created_at': u'2016-07-18T13:38:36Z',
#       u'default_branch': u'master',
#       u'deployments_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/deployments',
#       u'description': None,
#       u'downloads_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/downloads',
#       u'events_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/events',
#       u'fork': True,
#       u'forks': 0,
#       u'forks_count': 0,
#       u'forks_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/forks',
#       u'full_name': u'DryRun/levelOneHCALFM',
#       u'git_commits_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/git/tags{/sha}',
#       u'git_url': u'git://github.com/DryRun/levelOneHCALFM.git',
#       u'has_downloads': True,
#       u'has_issues': False,
#       u'has_pages': False,
#       u'has_wiki': True,
#       u'homepage': None,
#       u'hooks_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/hooks',
#       u'html_url': u'https://github.com/DryRun/levelOneHCALFM',
#       u'id': 63606048,
#       u'issue_comment_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/labels{/name}',
#       u'language': u'Java',
#       u'languages_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/languages',
#       u'merges_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/merges',
#       u'milestones_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'levelOneHCALFM',
#       u'notifications_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/notifications{?since,all,participating}',
#       u'open_issues': 0,
#       u'open_issues_count': 0,
#       u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1634307?v=3',
#        u'events_url': u'https://api.github.com/users/DryRun/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/DryRun/followers',
#        u'following_url': u'https://api.github.com/users/DryRun/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/DryRun/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/DryRun',
#        u'id': 1634307,
#        u'login': u'DryRun',
#        u'organizations_url': u'https://api.github.com/users/DryRun/orgs',
#        u'received_events_url': u'https://api.github.com/users/DryRun/received_events',
#        u'repos_url': u'https://api.github.com/users/DryRun/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/DryRun/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/DryRun/subscriptions',
#        u'type': u'User',
#        u'url': u'https://api.github.com/users/DryRun'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls{/number}',
#       u'pushed_at': u'2016-09-26T11:20:45Z',
#       u'releases_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/releases{/id}',
#       u'size': 2308,
#       u'ssh_url': u'git@github.com:DryRun/levelOneHCALFM.git',
#       u'stargazers_count': 0,
#       u'stargazers_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/subscription',
#       u'svn_url': u'https://github.com/DryRun/levelOneHCALFM',
#       u'tags_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/tags',
#       u'teams_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/teams',
#       u'trees_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/git/trees{/sha}',
#       u'updated_at': u'2016-07-18T13:38:37Z',
#       u'url': u'https://api.github.com/repos/DryRun/levelOneHCALFM',
#       u'watchers': 0,
#       u'watchers_count': 0},
#      u'sha': u'cedcdcb3e50591e2ea89dd54e2e9cc771912b260',
#      u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1634307?v=3',
#       u'events_url': u'https://api.github.com/users/DryRun/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/DryRun/followers',
#       u'following_url': u'https://api.github.com/users/DryRun/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/DryRun/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/DryRun',
#       u'id': 1634307,
#       u'login': u'DryRun',
#       u'organizations_url': u'https://api.github.com/users/DryRun/orgs',
#       u'received_events_url': u'https://api.github.com/users/DryRun/received_events',
#       u'repos_url': u'https://api.github.com/users/DryRun/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/DryRun/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/DryRun/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/DryRun'}},
#     u'body': u"I think it's better for you to create one big PR to the master, so that it's better recorded.\r\nSome of the commits are for AsyncFixes, which are already in Master. \r\nSo you can pull the master first and then the rest of the commits will be my fixes for the containers only",
#     u'changed_files': 5,
#     u'closed_at': u'2016-09-26T11:20:45Z',
#     u'comments': 0,
#     u'comments_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/1/comments',
#     u'commits': 17,
#     u'commits_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1/commits',
#     u'created_at': u'2016-09-24T16:02:56Z',
#     u'deletions': 236,
#     u'diff_url': u'https://github.com/DryRun/levelOneHCALFM/pull/1.diff',
#     u'head': {u'label': u'HCALRunControl:PartitionMaskingFromFEDList',
#      u'ref': u'PartitionMaskingFromFEDList',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/{archive_format}{/ref}',
#       u'assignees_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/branches{/branch}',
#       u'clone_url': u'https://github.com/HCALRunControl/levelOneHCALFM.git',
#       u'collaborators_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/contributors',
#       u'created_at': u'2015-10-23T13:09:12Z',
#       u'default_branch': u'master',
#       u'deployments_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/deployments',
#       u'description': u'',
#       u'downloads_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/downloads',
#       u'events_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/events',
#       u'fork': False,
#       u'forks': 4,
#       u'forks_count': 4,
#       u'forks_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/forks',
#       u'full_name': u'HCALRunControl/levelOneHCALFM',
#       u'git_commits_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/git/tags{/sha}',
#       u'git_url': u'git://github.com/HCALRunControl/levelOneHCALFM.git',
#       u'has_downloads': True,
#       u'has_issues': True,
#       u'has_pages': False,
#       u'has_wiki': True,
#       u'homepage': None,
#       u'hooks_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/hooks',
#       u'html_url': u'https://github.com/HCALRunControl/levelOneHCALFM',
#       u'id': 44813753,
#       u'issue_comment_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/labels{/name}',
#       u'language': u'Java',
#       u'languages_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/languages',
#       u'merges_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/merges',
#       u'milestones_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'levelOneHCALFM',
#       u'notifications_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/notifications{?since,all,participating}',
#       u'open_issues': 40,
#       u'open_issues_count': 40,
#       u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/18438152?v=3',
#        u'events_url': u'https://api.github.com/users/HCALRunControl/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/HCALRunControl/followers',
#        u'following_url': u'https://api.github.com/users/HCALRunControl/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/HCALRunControl/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/HCALRunControl',
#        u'id': 18438152,
#        u'login': u'HCALRunControl',
#        u'organizations_url': u'https://api.github.com/users/HCALRunControl/orgs',
#        u'received_events_url': u'https://api.github.com/users/HCALRunControl/received_events',
#        u'repos_url': u'https://api.github.com/users/HCALRunControl/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/HCALRunControl/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/HCALRunControl/subscriptions',
#        u'type': u'Organization',
#        u'url': u'https://api.github.com/users/HCALRunControl'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/pulls{/number}',
#       u'pushed_at': u'2016-09-26T11:20:02Z',
#       u'releases_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/releases{/id}',
#       u'size': 2341,
#       u'ssh_url': u'git@github.com:HCALRunControl/levelOneHCALFM.git',
#       u'stargazers_count': 0,
#       u'stargazers_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/subscription',
#       u'svn_url': u'https://github.com/HCALRunControl/levelOneHCALFM',
#       u'tags_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/tags',
#       u'teams_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/teams',
#       u'trees_url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM/git/trees{/sha}',
#       u'updated_at': u'2016-04-13T08:39:10Z',
#       u'url': u'https://api.github.com/repos/HCALRunControl/levelOneHCALFM',
#       u'watchers': 0,
#       u'watchers_count': 0},
#      u'sha': u'a24d8ab9c04d216aba613b7ff82f1e93b7d8fa06',
#      u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/18438152?v=3',
#       u'events_url': u'https://api.github.com/users/HCALRunControl/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/HCALRunControl/followers',
#       u'following_url': u'https://api.github.com/users/HCALRunControl/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/HCALRunControl/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/HCALRunControl',
#       u'id': 18438152,
#       u'login': u'HCALRunControl',
#       u'organizations_url': u'https://api.github.com/users/HCALRunControl/orgs',
#       u'received_events_url': u'https://api.github.com/users/HCALRunControl/received_events',
#       u'repos_url': u'https://api.github.com/users/HCALRunControl/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/HCALRunControl/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/HCALRunControl/subscriptions',
#       u'type': u'Organization',
#       u'url': u'https://api.github.com/users/HCALRunControl'}},
#     u'html_url': u'https://github.com/DryRun/levelOneHCALFM/pull/1',
#     u'id': 86621991,
#     u'issue_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/issues/1',
#     u'locked': False,
#     u'merge_commit_sha': u'f0296e5dcae9fc63d8872437d6f46f83b2a3ad03',
#     u'mergeable': None,
#     u'mergeable_state': u'unknown',
#     u'merged': True,
#     u'merged_at': u'2016-09-26T11:20:45Z',
#     u'merged_by': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1634307?v=3',
#      u'events_url': u'https://api.github.com/users/DryRun/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/DryRun/followers',
#      u'following_url': u'https://api.github.com/users/DryRun/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/DryRun/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/DryRun',
#      u'id': 1634307,
#      u'login': u'DryRun',
#      u'organizations_url': u'https://api.github.com/users/DryRun/orgs',
#      u'received_events_url': u'https://api.github.com/users/DryRun/received_events',
#      u'repos_url': u'https://api.github.com/users/DryRun/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/DryRun/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/DryRun/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/DryRun'},
#     u'milestone': None,
#     u'number': 1,
#     u'patch_url': u'https://github.com/DryRun/levelOneHCALFM/pull/1.patch',
#     u'review_comment_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/comments{/number}',
#     u'review_comments': 0,
#     u'review_comments_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1/comments',
#     u'state': u'closed',
#     u'statuses_url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/statuses/a24d8ab9c04d216aba613b7ff82f1e93b7d8fa06',
#     u'title': u'Partition masking from fed list',
#     u'updated_at': u'2016-09-26T11:20:45Z',
#     u'url': u'https://api.github.com/repos/DryRun/levelOneHCALFM/pulls/1',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/12798013?v=3',
#      u'events_url': u'https://api.github.com/users/kakwok/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/kakwok/followers',
#      u'following_url': u'https://api.github.com/users/kakwok/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/kakwok/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/kakwok',
#      u'id': 12798013,
#      u'login': u'kakwok',
#      u'organizations_url': u'https://api.github.com/users/kakwok/orgs',
#      u'received_events_url': u'https://api.github.com/users/kakwok/received_events',
#      u'repos_url': u'https://api.github.com/users/kakwok/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/kakwok/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/kakwok/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/kakwok'}}},
#   u'public': True,
#   u'repo': {u'id': 63606048,
#    u'name': u'DryRun/levelOneHCALFM',
#    u'url': u'https://api.github.com/repos/DryRun/levelOneHCALFM'},
#   u'type': u'PullRequestEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/909468?',
#    u'display_login': u'digitalchild',
#    u'gravatar_id': u'',
#    u'id': 909468,
#    u'login': u'digitalchild',
#    u'url': u'https://api.github.com/users/digitalchild'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188950',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8187088?',
#    u'gravatar_id': u'',
#    u'id': 8187088,
#    u'login': u'wcvendors',
#    u'url': u'https://api.github.com/orgs/wcvendors'},
#   u'payload': {u'before': u'c3a35fce87fce66b21234596e32c7405ed50c34f',
#    u'commits': [{u'author': {u'email': u'digitalchild@gmail.com',
#       u'name': u'digitalchild'},
#      u'distinct': True,
#      u'message': u'Added: Start / End Times to auction times #5',
#      u'sha': u'890b3c4b03755d1f244d49a1f4c2324070b379ac',
#      u'url': u'https://api.github.com/repos/wcvendors/wcvendors-pro-simple-auctions/commits/890b3c4b03755d1f244d49a1f4c2324070b379ac'}],
#    u'distinct_size': 1,
#    u'head': u'890b3c4b03755d1f244d49a1f4c2324070b379ac',
#    u'push_id': 1316921986,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 49272296,
#    u'name': u'wcvendors/wcvendors-pro-simple-auctions',
#    u'url': u'https://api.github.com/repos/wcvendors/wcvendors-pro-simple-auctions'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1674432?',
#    u'display_login': u'anthoq88',
#    u'gravatar_id': u'',
#    u'id': 1674432,
#    u'login': u'anthoq88',
#    u'url': u'https://api.github.com/users/anthoq88'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188949',
#   u'payload': {u'before': u'6dda368aef022bc5b02ecb4ae396a424c2641936',
#    u'commits': [{u'author': {u'email': u'anthoq88@gmail.com',
#       u'name': u'Anthony Quizon'},
#      u'distinct': True,
#      u'message': u'install dir',
#      u'sha': u'd4febec11f5121a8b751f4d8289ba2dab60221b4',
#      u'url': u'https://api.github.com/repos/anthoq88/dotfiles/commits/d4febec11f5121a8b751f4d8289ba2dab60221b4'}],
#    u'distinct_size': 1,
#    u'head': u'd4febec11f5121a8b751f4d8289ba2dab60221b4',
#    u'push_id': 1316921985,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 6207982,
#    u'name': u'anthoq88/dotfiles',
#    u'url': u'https://api.github.com/repos/anthoq88/dotfiles'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/16267135?',
#    u'display_login': u'yaysh',
#    u'gravatar_id': u'',
#    u'id': 16267135,
#    u'login': u'yaysh',
#    u'url': u'https://api.github.com/users/yaysh'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188945',
#   u'payload': {u'description': None,
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': None,
#    u'ref_type': u'repository'},
#   u'public': True,
#   u'repo': {u'id': 69242916,
#    u'name': u'yaysh/725G85_Uppgift_6',
#    u'url': u'https://api.github.com/repos/yaysh/725G85_Uppgift_6'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/15228958?',
#    u'display_login': u'diqidaihuoying',
#    u'gravatar_id': u'',
#    u'id': 15228958,
#    u'login': u'diqidaihuoying',
#    u'url': u'https://api.github.com/users/diqidaihuoying'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188941',
#   u'payload': {u'description': None,
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': u'master',
#    u'ref_type': u'branch'},
#   u'public': True,
#   u'repo': {u'id': 69240701,
#    u'name': u'diqidaihuoying/wtprogject',
#    u'url': u'https://api.github.com/repos/diqidaihuoying/wtprogject'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1035625?',
#    u'display_login': u'marquiz',
#    u'gravatar_id': u'',
#    u'id': 1035625,
#    u'login': u'marquiz',
#    u'url': u'https://api.github.com/users/marquiz'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188936',
#   u'payload': {u'before': u'003eb30696677bcccbb2621f3655c8403c4bcd2f',
#    u'commits': [{u'author': {u'email': u'markus.lehtonen@linux.intel.com',
#       u'name': u'Markus Lehtonen'},
#      u'distinct': True,
#      u'message': u'xinitrc: set right display into portrait orientation\n\nSigned-off-by: Markus Lehtonen <markus.lehtonen@linux.intel.com>',
#      u'sha': u'095016c34691e46ba1f77b6ff2a45873085f4155',
#      u'url': u'https://api.github.com/repos/marquiz/user-configs/commits/095016c34691e46ba1f77b6ff2a45873085f4155'},
#     {u'author': {u'email': u'markus.lehtonen@linux.intel.com',
#       u'name': u'Markus Lehtonen'},
#      u'distinct': True,
#      u'message': u'xinitrc: add third display\n\nPortrait mode, on the left\n\nSigned-off-by: Markus Lehtonen <markus.lehtonen@linux.intel.com>',
#      u'sha': u'ac3f13ef522632a41df1570669cea1d59d57a488',
#      u'url': u'https://api.github.com/repos/marquiz/user-configs/commits/ac3f13ef522632a41df1570669cea1d59d57a488'}],
#    u'distinct_size': 2,
#    u'head': u'ac3f13ef522632a41df1570669cea1d59d57a488',
#    u'push_id': 1316921981,
#    u'ref': u'refs/heads/openSUSE',
#    u'size': 2},
#   u'public': True,
#   u'repo': {u'id': 10471432,
#    u'name': u'marquiz/user-configs',
#    u'url': u'https://api.github.com/repos/marquiz/user-configs'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1200081?',
#    u'display_login': u'gambuzzi',
#    u'gravatar_id': u'',
#    u'id': 1200081,
#    u'login': u'gambuzzi',
#    u'url': u'https://api.github.com/users/gambuzzi'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188933',
#   u'payload': {u'before': u'b523c06e8f276ac0a5420866db97be898367a61b',
#    u'commits': [{u'author': {u'email': u'gambuzzi@gbinside.com',
#       u'name': u'Roberto Gambuzzi'},
#      u'distinct': True,
#      u'message': u'autocommit',
#      u'sha': u'68ccbcd345d0c0a27b0ec50023bca4b4083f44f6',
#      u'url': u'https://api.github.com/repos/gambuzzi/gambuzzi.github.io/commits/68ccbcd345d0c0a27b0ec50023bca4b4083f44f6'}],
#    u'distinct_size': 1,
#    u'head': u'68ccbcd345d0c0a27b0ec50023bca4b4083f44f6',
#    u'push_id': 1316921977,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 41860130,
#    u'name': u'gambuzzi/gambuzzi.github.io',
#    u'url': u'https://api.github.com/repos/gambuzzi/gambuzzi.github.io'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/17061547?',
#    u'display_login': u'Khmelov',
#    u'gravatar_id': u'',
#    u'id': 17061547,
#    u'login': u'Khmelov',
#    u'url': u'https://api.github.com/users/Khmelov'},
#   u'created_at': u'2016-09-26T11:20:45Z',
#   u'id': u'4617188926',
#   u'payload': {u'action': u'closed',
#    u'number': 81,
#    u'pull_request': {u'_links': {u'comments': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/issues/81/comments'},
#      u'commits': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/pulls/81/commits'},
#      u'html': {u'href': u'https://github.com/Khmelov/JD2016-08-22/pull/81'},
#      u'issue': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/issues/81'},
#      u'review_comment': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/pulls/comments{/number}'},
#      u'review_comments': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/pulls/81/comments'},
#      u'self': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/pulls/81'},
#      u'statuses': {u'href': u'https://api.github.com/repos/Khmelov/JD2016-08-22/statuses/7b74d7fa3a4e8231327eaa6bfb6572e079ff9231'}},
#     u'additions': 240,
#     u'assignee': None,
#     u'assignees': [],
#     u'base': {u'label': u'Khmelov:master',
#      u'ref': u'master',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/{archive_format}{/ref}',
#       u'assignees_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/branches{/branch}',
#       u'clone_url': u'https://github.com/Khmelov/JD2016-08-22.git',
#       u'collaborators_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/contributors',
#       u'created_at': u'2016-08-31T13:51:55Z',
#       u'default_branch': u'master',
#       u'deployments_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/deployments',
#       u'description': u'\u0412\u0415\u0427\u0415\u0420\u041d\u042f\u042f \u0413\u0420\u0423\u041f\u041f\u0410 \u043d\u0430 \u043a\u0443\u0440\u0441 JD01-03. \u041d\u0430\u0431\u043e\u0440 \u0441\u0442\u0430\u0440\u0442\u043e\u0432\u0430\u043b JD2016-08-22.',
#       u'downloads_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/downloads',
#       u'events_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/events',
#       u'fork': False,
#       u'forks': 14,
#       u'forks_count': 14,
#       u'forks_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/forks',
#       u'full_name': u'Khmelov/JD2016-08-22',
#       u'git_commits_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/git/tags{/sha}',
#       u'git_url': u'git://github.com/Khmelov/JD2016-08-22.git',
#       u'has_downloads': True,
#       u'has_issues': True,
#       u'has_pages': False,
#       u'has_wiki': True,
#       u'homepage': u'http://tinyurl.com/jd2016-08-22',
#       u'hooks_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/hooks',
#       u'html_url': u'https://github.com/Khmelov/JD2016-08-22',
#       u'id': 67041809,
#       u'issue_comment_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/labels{/name}',
#       u'language': u'Java',
#       u'languages_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/languages',
#       u'merges_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/merges',
#       u'milestones_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'JD2016-08-22',
#       u'notifications_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/notifications{?since,all,participating}',
#       u'open_issues': 3,
#       u'open_issues_count': 3,
#       u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/17061547?v=3',
#        u'events_url': u'https://api.github.com/users/Khmelov/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/Khmelov/followers',
#        u'following_url': u'https://api.github.com/users/Khmelov/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/Khmelov/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/Khmelov',
#        u'id': 17061547,
#        u'login': u'Khmelov',
#        u'organizations_url': u'https://api.github.com/users/Khmelov/orgs',
#        u'received_events_url': u'https://api.github.com/users/Khmelov/received_events',
#        u'repos_url': u'https://api.github.com/users/Khmelov/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/Khmelov/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/Khmelov/subscriptions',
#        u'type': u'User',
#        u'url': u'https://api.github.com/users/Khmelov'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/pulls{/number}',
#       u'pushed_at': u'2016-09-26T11:20:45Z',
#       u'releases_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/releases{/id}',
#       u'size': 612,
#       u'ssh_url': u'git@github.com:Khmelov/JD2016-08-22.git',
#       u'stargazers_count': 0,
#       u'stargazers_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/Khmelov/JD2016-08-22/subscription',
#       u'svn_url': u'https://github.com/Khmelov/JD2016-08-22',
# ...
#       u'open_issues': 148,
#       u'open_issues_count': 148,
#       u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1503512?v=3',
#        u'events_url': u'https://api.github.com/users/Homebrew/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/Homebrew/followers',
#        u'following_url': u'https://api.github.com/users/Homebrew/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/Homebrew/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/Homebrew',
#        u'id': 1503512,
#        u'login': u'Homebrew',
#        u'organizations_url': u'https://api.github.com/users/Homebrew/orgs',
#        u'received_events_url': u'https://api.github.com/users/Homebrew/received_events',
#        u'repos_url': u'https://api.github.com/users/Homebrew/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/Homebrew/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/Homebrew/subscriptions',
#        u'type': u'Organization',
#        u'url': u'https://api.github.com/users/Homebrew'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/Homebrew/homebrew-core/pulls{/number}',
#       u'pushed_at': u'2016-09-26T11:20:43Z',
#       u'releases_url': u'https://api.github.com/repos/Homebrew/homebrew-core/releases{/id}',
#       u'size': 122843,
#       u'ssh_url': u'git@github.com:Homebrew/homebrew-core.git',
#       u'stargazers_count': 821,
#       u'stargazers_url': u'https://api.github.com/repos/Homebrew/homebrew-core/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/Homebrew/homebrew-core/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/Homebrew/homebrew-core/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/Homebrew/homebrew-core/subscription',
#       u'svn_url': u'https://github.com/Homebrew/homebrew-core',
#       u'tags_url': u'https://api.github.com/repos/Homebrew/homebrew-core/tags',
#       u'teams_url': u'https://api.github.com/repos/Homebrew/homebrew-core/teams',
#       u'trees_url': u'https://api.github.com/repos/Homebrew/homebrew-core/git/trees{/sha}',
#       u'updated_at': u'2016-09-25T16:55:39Z',
#       u'url': u'https://api.github.com/repos/Homebrew/homebrew-core',
#       u'watchers': 821,
#       u'watchers_count': 821},
#      u'sha': u'1709e480841f7794d2c5061890a4d664054ffc79',
#      u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1503512?v=3',
#       u'events_url': u'https://api.github.com/users/Homebrew/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/Homebrew/followers',
#       u'following_url': u'https://api.github.com/users/Homebrew/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/Homebrew/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/Homebrew',
#       u'id': 1503512,
#       u'login': u'Homebrew',
#       u'organizations_url': u'https://api.github.com/users/Homebrew/orgs',
#       u'received_events_url': u'https://api.github.com/users/Homebrew/received_events',
#       u'repos_url': u'https://api.github.com/users/Homebrew/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/Homebrew/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/Homebrew/subscriptions',
#       u'type': u'Organization',
#       u'url': u'https://api.github.com/users/Homebrew'}},
#     u'body': u'Created with `brew bump-formula-pr`.',
#     u'changed_files': 1,
#     u'closed_at': u'2016-09-26T11:20:43Z',
#     u'comments': 0,
#     u'comments_url': u'https://api.github.com/repos/Homebrew/homebrew-core/issues/5243/comments',
#     u'commits': 1,
#     u'commits_url': u'https://api.github.com/repos/Homebrew/homebrew-core/pulls/5243/commits',
#     u'created_at': u'2016-09-26T07:55:57Z',
#     u'deletions': 2,
#     u'diff_url': u'https://github.com/Homebrew/homebrew-core/pull/5243.diff',
#     u'head': {u'label': u'ilovezfs:pgrouting-2.3.0-rc1',
#      u'ref': u'pgrouting-2.3.0-rc1',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/{archive_format}{/ref}',
#       u'assignees_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/branches{/branch}',
#       u'clone_url': u'https://github.com/ilovezfs/homebrew-core.git',
#       u'collaborators_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/contributors',
#       u'created_at': u'2016-04-04T05:59:03Z',
#       u'default_branch': u'master',
#       u'deployments_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/deployments',
#       u'description': u':beers: Core formulae for the Homebrew package manager',
#       u'downloads_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/downloads',
#       u'events_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/events',
#       u'fork': True,
#       u'forks': 0,
#       u'forks_count': 0,
#       u'forks_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/forks',
#       u'full_name': u'ilovezfs/homebrew-core',
#       u'git_commits_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/git/tags{/sha}',
#       u'git_url': u'git://github.com/ilovezfs/homebrew-core.git',
#       u'has_downloads': True,
#       u'has_issues': False,
#       u'has_pages': False,
#       u'has_wiki': False,
#       u'homepage': u'http://brew.sh',
#       u'hooks_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/hooks',
#       u'html_url': u'https://github.com/ilovezfs/homebrew-core',
#       u'id': 55388441,
#       u'issue_comment_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/labels{/name}',
#       u'language': u'Ruby',
#       u'languages_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/languages',
#       u'merges_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/merges',
#       u'milestones_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'homebrew-core',
#       u'notifications_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/notifications{?since,all,participating}',
#       u'open_issues': 0,
#       u'open_issues_count': 0,
#       u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/5268928?v=3',
#        u'events_url': u'https://api.github.com/users/ilovezfs/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/ilovezfs/followers',
#        u'following_url': u'https://api.github.com/users/ilovezfs/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/ilovezfs/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/ilovezfs',
#        u'id': 5268928,
#        u'login': u'ilovezfs',
#        u'organizations_url': u'https://api.github.com/users/ilovezfs/orgs',
#        u'received_events_url': u'https://api.github.com/users/ilovezfs/received_events',
#        u'repos_url': u'https://api.github.com/users/ilovezfs/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/ilovezfs/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/ilovezfs/subscriptions',
#        u'type': u'User',
#        u'url': u'https://api.github.com/users/ilovezfs'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/pulls{/number}',
#       u'pushed_at': u'2016-09-26T10:01:52Z',
#       u'releases_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/releases{/id}',
#       u'size': 79162,
#       u'ssh_url': u'git@github.com:ilovezfs/homebrew-core.git',
#       u'stargazers_count': 0,
#       u'stargazers_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/subscription',
#       u'svn_url': u'https://github.com/ilovezfs/homebrew-core',
#       u'tags_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/tags',
#       u'teams_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/teams',
#       u'trees_url': u'https://api.github.com/repos/ilovezfs/homebrew-core/git/trees{/sha}',
#       u'updated_at': u'2016-04-04T05:59:16Z',
#       u'url': u'https://api.github.com/repos/ilovezfs/homebrew-core',
#       u'watchers': 0,
#       u'watchers_count': 0},
#      u'sha': u'7e4f604b601772a1b7032081a8c6d77439d246a1',
#      u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/5268928?v=3',
#       u'events_url': u'https://api.github.com/users/ilovezfs/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/ilovezfs/followers',
#       u'following_url': u'https://api.github.com/users/ilovezfs/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/ilovezfs/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/ilovezfs',
#       u'id': 5268928,
#       u'login': u'ilovezfs',
#       u'organizations_url': u'https://api.github.com/users/ilovezfs/orgs',
#       u'received_events_url': u'https://api.github.com/users/ilovezfs/received_events',
#       u'repos_url': u'https://api.github.com/users/ilovezfs/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/ilovezfs/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/ilovezfs/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/ilovezfs'}},
#     u'html_url': u'https://github.com/Homebrew/homebrew-core/pull/5243',
#     u'id': 86696206,
#     u'issue_url': u'https://api.github.com/repos/Homebrew/homebrew-core/issues/5243',
#     u'locked': False,
#     u'merge_commit_sha': u'6af4f4f1857fa30011ce7b0535ab16cf3c392a42',
#     u'mergeable': None,
#     u'mergeable_state': u'unknown',
#     u'merged': True,
#     u'merged_at': u'2016-09-26T11:20:43Z',
#     u'merged_by': {u'avatar_url': u'https://avatars.githubusercontent.com/u/5268928?v=3',
#      u'events_url': u'https://api.github.com/users/ilovezfs/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/ilovezfs/followers',
#      u'following_url': u'https://api.github.com/users/ilovezfs/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/ilovezfs/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/ilovezfs',
#      u'id': 5268928,
#      u'login': u'ilovezfs',
#      u'organizations_url': u'https://api.github.com/users/ilovezfs/orgs',
#      u'received_events_url': u'https://api.github.com/users/ilovezfs/received_events',
#      u'repos_url': u'https://api.github.com/users/ilovezfs/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/ilovezfs/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/ilovezfs/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/ilovezfs'},
#     u'milestone': None,
#     u'number': 5243,
#     u'patch_url': u'https://github.com/Homebrew/homebrew-core/pull/5243.patch',
#     u'review_comment_url': u'https://api.github.com/repos/Homebrew/homebrew-core/pulls/comments{/number}',
#     u'review_comments': 0,
#     u'review_comments_url': u'https://api.github.com/repos/Homebrew/homebrew-core/pulls/5243/comments',
#     u'state': u'closed',
#     u'statuses_url': u'https://api.github.com/repos/Homebrew/homebrew-core/statuses/7e4f604b601772a1b7032081a8c6d77439d246a1',
#     u'title': u'pgrouting 2.3.0-rc1 (devel)',
#     u'updated_at': u'2016-09-26T11:20:43Z',
#     u'url': u'https://api.github.com/repos/Homebrew/homebrew-core/pulls/5243',
#     u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/5268928?v=3',
#      u'events_url': u'https://api.github.com/users/ilovezfs/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/ilovezfs/followers',
#      u'following_url': u'https://api.github.com/users/ilovezfs/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/ilovezfs/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/ilovezfs',
#      u'id': 5268928,
#      u'login': u'ilovezfs',
#      u'organizations_url': u'https://api.github.com/users/ilovezfs/orgs',
#      u'received_events_url': u'https://api.github.com/users/ilovezfs/received_events',
#      u'repos_url': u'https://api.github.com/users/ilovezfs/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/ilovezfs/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/ilovezfs/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/ilovezfs'}}},
#   u'public': True,
#   u'repo': {u'id': 52855516,
#    u'name': u'Homebrew/homebrew-core',
#    u'url': u'https://api.github.com/repos/Homebrew/homebrew-core'},
#   u'type': u'PullRequestEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/426623?',
#    u'display_login': u'2ooom',
#    u'gravatar_id': u'',
#    u'id': 426623,
#    u'login': u'2ooom',
#    u'url': u'https://api.github.com/users/2ooom'},
#   u'created_at': u'2016-09-26T11:20:44Z',
#   u'id': u'4617188864',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1713646?',
#    u'gravatar_id': u'',
#    u'id': 1713646,
#    u'login': u'criteo',
#    u'url': u'https://api.github.com/orgs/criteo'},
#   u'payload': {u'action': u'started'},
#   u'public': True,
#   u'repo': {u'id': 17289211,
#    u'name': u'criteo/memcache-driver',
#    u'url': u'https://api.github.com/repos/criteo/memcache-driver'},
#   u'type': u'WatchEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/15373547?',
#    u'display_login': u'jixinlo',
#    u'gravatar_id': u'',
#    u'id': 15373547,
#    u'login': u'jixinlo',
#    u'url': u'https://api.github.com/users/jixinlo'},
#   u'created_at': u'2016-09-26T11:20:44Z',
#   u'id': u'4617188859',
#   u'payload': {u'before': u'0620cd44002506d1919598ab0185cda011c9832f',
#    u'commits': [{u'author': {u'email': u'jixinlo@users.noreply.github.com',
#       u'name': u'jixinlo'},
#      u'distinct': True,
#      u'message': u'Add files via upload',
#      u'sha': u'aa99d7f377ad5751d9fec26eec7384a3fa8678ff',
#      u'url': u'https://api.github.com/repos/jixinlo/jixinlo.github.io/commits/aa99d7f377ad5751d9fec26eec7384a3fa8678ff'}],
#    u'distinct_size': 1,
#    u'head': u'aa99d7f377ad5751d9fec26eec7384a3fa8678ff',
#    u'push_id': 1316921944,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 54196628,
#    u'name': u'jixinlo/jixinlo.github.io',
#    u'url': u'https://api.github.com/repos/jixinlo/jixinlo.github.io'},
#   u'type': u'PushEvent'}]

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})

# %%
r.json()
# Out:
# {u'args': {},
#  u'data': u'',
#  u'files': {},
#  u'form': {u'key': u'value'},
#  u'headers': {u'Accept': u'*/*',
#   u'Accept-Encoding': u'gzip, deflate',
#   u'Content-Length': u'9',
#   u'Content-Type': u'application/x-www-form-urlencoded',
#   u'Host': u'httpbin.org',
#   u'User-Agent': u'python-requests/2.7.0 CPython/2.7.10 Darwin/15.5.0'},
#  u'json': None,
#  u'origin': u'185.6.245.156',
#  u'url': u'http://httpbin.org/post'}

# %%
r.text
# Out:
# u'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.7.0 CPython/2.7.10 Darwin/15.5.0"\n  }, \n  "json": null, \n  "origin": "185.6.245.156", \n  "url": "http://httpbin.org/post"\n}\n'

# %%
r.url
# Out:
# u'http://httpbin.org/post'
